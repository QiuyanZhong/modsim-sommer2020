% %% [markdown]
% # Aufgabenblatt 3, Aufgabe 2  - Vertiefung zum Hodgkin-Huxley-Modell
% ***Autoren:*** (Bitte ergänzen Sie hier), ***Datum:*** 21.11.19

% %%
%plot -f svg

% %% [markdown]
% ## Aufgabenteil a)

% %%
function value=nmodel(t, tau, ninfty, n0)
    value = ninfty + (n0-ninfty) * exp(-t/tau);
endfunction

% %% [markdown]
% ## Aufgabenteil b)
% Vektoren:

% %%
t = [0 1 2 3 4 6 8 10 15 20]
nexp = [0.1 0.27 0.41 0.52 0.57 0.69 0.73 0.78 0.80 0.75]
% Out:
% t =
%
%     0    1    2    3    4    6    8   10   15   20
%
% nexp =
%
%  Columns 1 through 8:
%
%    0.10000   0.27000   0.41000   0.52000   0.57000   0.69000   0.73000   0.78000
%
%  Columns 9 and 10:
%
%    0.80000   0.75000

% %% [markdown]
% Bitte wählen Sie hier geeignete Parameter:

% %%
parameter.n0 = 0.0;
parameter.ninfty = 2.0;
parameter.tau = 1.0;

napprox = nmodel(t, parameter.tau, parameter.ninfty, parameter.n0)

newplot()
hold on
plot(t, nexp, 'color', 'blue')
plot(t, nsim)
% Out:
% nsim =
%
%  Columns 1 through 8:
%
%    0.00000   1.26424   1.72933   1.90043   1.96337   1.99504   1.99933   1.99991
%
%  Columns 9 and 10:
%
%    2.00000   2.00000

% %% [markdown]
% Ggf. hilfreich:

% %%
help fminsearch

% %% [markdown]
% ## Aufgabenteil c)

% %%
Voltage = [-90 -70 -50 0 30 60 100]
ninfty = [0.06 0.25 0.58 0.93 0.99 0.99 0.97]
tau =[ 5.5 5.56 4.56 1.70 1.10 0.82 0.87]
% Out:
% Voltage =
%
%    -90   -70   -50     0    30    60   100
%
% ninfty =
%
%    0.060000   0.250000   0.580000   0.930000   0.990000   0.990000   0.970000
%
% tau =
%
%    5.50000   5.56000   4.56000   1.70000   1.10000   0.82000   0.87000

% %%
plot(Voltage, ninfty, 'color', 'blue')

% %%
plot(Voltage, tau, 'color', 'blue')
